# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 df = pd.read_csv(r"C:\Users\TIBU\Downloads\CodvedaProject\3) Sentiment dataset.csv")
df #display dataframe
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
df = df.drop(columns=["Unnamed: 0.1", "Unnamed: 0", "Timestamp", "User"])
df
# Out:
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# 728  Attending a surprise birthday party organized ...       Happy
# 729  Successfully fundraising for a school charity ...       Happy
# 730  Participating in a multicultural festival, cel...       Happy
# 731  Organizing a virtual talent show during challe...       Happy
#
#         Platform                                       Hashtags  Retweets  \
# 0      Twitter        #Nature #Park                                  15.0
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# 728  Attending a surprise birthday party organized ...       Happy
# 729  Successfully fundraising for a school charity ...       Happy
# 730  Participating in a multicultural festival, cel...       Happy
# 731  Organizing a virtual talent show during challe...       Happy
#
#         Platform                                       Hashtags  Retweets  \
# 0      Twitter        #Nature #Park                                  15.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 711 entries, 0 to 731
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       711 non-null    object
#  1   Sentiment  711 non-null    object
#  2   Platform   711 non-null    object
#  3   Hashtags   711 non-null    object
#  4   Retweets   711 non-null    float64
#  5   Likes      711 non-null    float64
#  6   Country    711 non-null    object
#  7   Year       711 non-null    int64
#  8   Month      711 non-null    int64
#  9   Day        711 non-null    int64
#  10  Hour       711 non-null    int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 66.7+ KB

# %%
num_cols = ['Retweets', 'Likes', 'Year', 'Month', 'Day', 'Hour']

# %%
df[num_cols].mean()
# Out:
# Retweets      21.555556
# Likes         42.992968
# Year        2020.479606
# Month          6.105485
# Day           15.510549
# Hour          15.594937
# dtype: float64

# %%
df[num_cols].median()
# Out:
# Retweets      22.0
# Likes         43.0
# Year        2021.0
# Month          6.0
# Day           15.0
# Hour          16.0
# dtype: float64

# %%
df[num_cols].mode().iloc[0]
# Out:
# Retweets      22.0
# Likes         45.0
# Year        2023.0
# Month          2.0
# Day           15.0
# Hour          14.0
# Name: 0, dtype: float64

# %%
df[num_cols].std()
# Out:
# Retweets     7.120844
# Likes       14.208159
# Year         2.828789
# Month        3.407756
# Day          8.450325
# Hour         4.065198
# dtype: float64

# %%
df[num_cols].hist(bins=20, figsize=(12,8))
plt.suptitle("Histograms of Numerical Features")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df[num_cols])
plt.title("Boxplots of Numerical Features")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x="Hour", y="Likes", data=df)
plt.title("Scatter Plot: Hour vs Likes")
plt.show()

# %%
corr = df.corr(numeric_only=True)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %%
avg_likes_platform = df.groupby("Platform")["Likes"].mean().reset_index()
avg_likes_platform = avg_likes_platform.sort_values("Likes", ascending=False)

plt.figure(figsize=(8,5))
plt.bar(avg_likes_platform["Platform"], avg_likes_platform["Likes"], color="skyblue")
plt.title("Average Likes by Platform", fontsize=14)
plt.xlabel("Platform")
plt.ylabel("Average Likes")
plt.tight_layout()
plt.savefig("barplot_avg_likes_platform.png", dpi=300)
plt.show()

# %%
likes_trend = df.groupby("Year")["Likes"].mean().reset_index()

plt.figure(figsize=(10,6))
plt.plot(likes_trend["Year"], likes_trend["Likes"], marker="o", color="blue", label="Average Likes")
plt.title("Average Likes Trend Over Years", fontsize=14)
plt.xlabel("Year")
plt.ylabel("Average Likes")
plt.legend()
plt.tight_layout()
plt.savefig("linechart_likes_trend.png", dpi=300)
plt.show()

# %%
scatter_sample = df.sample(200, random_state=42)

plt.figure(figsize=(8,6))
sns.scatterplot(x="Retweets", y="Likes", hue="Platform", data=scatter_sample, alpha=0.7, palette="tab10")
plt.title("Scatter Plot: Likes vs Retweets by Platform", fontsize=14)
plt.xlabel("Retweets")
plt.ylabel("Likes")
plt.legend(title="Platform")
plt.tight_layout()
plt.savefig("scatter_likes_retweets_sample.png", dpi=300)
plt.show()
